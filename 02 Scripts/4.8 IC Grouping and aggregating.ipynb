# %% [markdown]
# # 4.8  Grouping & Aggregating
#
# #This Script Contains following:
#
# #1 Importing Libraries
#
# #2 Importing path & Dataset
#
# #3 Grouping of Data
#
# #4 Performing multiple aggregation
#
# #5 Creating Flag
#
# #6 Deriving Columns with loc()
#
# #7 Exporting Clean & aggregated Dataset in pickle format

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
#Defining path
path=r'C:\Users\User01\16.05.2023 Instacart Basket Analysis'

# %%
# Importing order_products_merged
ords_prods_merge= pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_updated.pkl'))

# %% [markdown]
# # Grouping data as per Product Name

# %%
ords_prods_merge.groupby('product_name')

# %% [markdown]
# # Performing multiple aggregation on entire dataset

# %%
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.455255   1  99
# 2                17.248522   1  99
# 3                17.169687   1  99
# 4                17.808925   1  99
# 5                15.212750   1  99
# 6                16.442749   1  99
# 7                17.227292   1  99
# 8                15.342914   1  99
# 9                15.904623   1  99
# 10               20.257219   1  99
# 11               16.172317   1  99
# 12               15.936575   1  99
# 13               16.568776   1  99
# 14               16.776753   1  99
# 15               16.211907   1  99
# 16               17.676900   1  99
# 17               15.676384   1  99
# 18               19.299330   1  99
# 19               17.176997   1  99
# 20               16.475588   1  99
# 21               22.906849   1  99

# %% [markdown]
# # Results are same as that of subset data since, minimum orders will always be 1 and the maximum has been capped at 99 by the data engineers at Instacart.

# %% [markdown]
# # Create a loyalty flag using loc

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
# 5                    19.0         196                  1          1
# 6                    20.0         196                  1          1
# 7                    14.0         196                  2          1
# 8                     0.0         196                  4          1
# 9                    30.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices _merge  \
# 0         195         Soda        77              7     9.0   both
# 1         195         Soda        77              7     9.0   both
# 2         195         Soda        77              7     9.0   both
# 3         195         Soda        77              7     9.0   both
# 4         195         Soda        77              7     9.0   both
# 5         195         Soda        77              7     9.0   both
# 6         195         Soda        77              7     9.0   both
# 7         195         Soda        77              7     9.0   both
# 8         195         Soda        77              7     9.0   both
# 9         195         Soda        77              7     9.0   both
#
#      price_range_loc     busiest_day        busiest_days  \
# 0  Mid-range product  Regularly busy  Regularly busy day
# 1  Mid-range product  Regularly busy     Least busy days
# 2  Mid-range product  Regularly busy     Least busy days
# 3  Mid-range product      Least busy     Least busy days
# 4  Mid-range product      Least busy     Least busy days
# 5  Mid-range product  Regularly busy  Regularly busy day
# 6  Mid-range product  Regularly busy        Busiest days
# 7  Mid-range product  Regularly busy        Busiest days
# 8  Mid-range product  Regularly busy        Busiest days
# 9  Mid-range product      Least busy     Least busy days
#
#   busiest_period_of_day  max_order
# 0        Average orders         10
# 1        Average orders         10
# 2           Most orders         10
# 3        Average orders         10
# 4           Most orders         10
# 5        Average orders         10
# 6           Most orders         10
# 7           Most orders         10
# 8           Most orders         10
# 9        Average orders         10

# %% [markdown]
# # Deriving Columns with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna=False)
# Out:
# Regular customer    15553342
# Loyal customer      10093365
# New customer         6114570
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# # Determine mean of product prices by loyalty group

# %%
# Group by "prices" 
ords_prods_merge.groupby('prices')

# %%
# Split the data into groups by "loyalty_flag" and then calculate the mean for each "prices" column
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean']})
# Out:
#                     prices
#                       mean
# loyalty_flag
# Loyal customer    7.641987
# New customer      7.645179
# Regular customer  7.645539

# %% [markdown]
# # Creating Spending Flag of each user based on Avg. Price

# %%
# Group data by "user_id" column, generate mean product price for each user, create "mean_price" for aggregation results
ords_prods_merge['mean_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0  ... department_id  prices  _merge    price_range_loc  \
# 0         195  ...             7     9.0    both  Mid-range product
# 1         195  ...             7     9.0    both  Mid-range product
# 2         195  ...             7     9.0    both  Mid-range product
# 3         195  ...             7     9.0    both  Mid-range product
# 4         195  ...             7     9.0    both  Mid-range product
#
#       busiest_day        busiest_days busiest_period_of_day max_order  \
# 0  Regularly busy  Regularly busy day        Average orders        10
# 1  Regularly busy     Least busy days        Average orders        10
# 2  Regularly busy     Least busy days           Most orders        10
# 3      Least busy     Least busy days        Average orders        10
# 4      Least busy     Least busy days           Most orders        10
#
#    loyalty_flag  mean_price
# 0  New customer    6.391379
# 1  New customer    6.391379
# 2  New customer    6.391379
# 3  New customer    6.391379
# 4  New customer    6.391379
#
# [5 rows x 22 columns]

# %% [markdown]
# # Deriving Spender Column with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['mean_price'] >=10, 'spender_flag'] = 'High Spender'

# %%
ords_prods_merge.loc[ords_prods_merge['mean_price'] <10, 'spender_flag'] = 'Low Spender'

# %%
ords_prods_merge['spender_flag'].value_counts(dropna=False)
# Out:
# Low Spender     31705481
# High Spender       55796
# Name: spender_flag, dtype: int64

# %% [markdown]
# # Create order frequency flag that indicates users' ordering behavior.

# %%
# Group data by "user_id" column, generate median product of "days since prior order, create "median_days" for aggregation results
ords_prods_merge['median_days'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0  ... _merge    price_range_loc     busiest_day  \
# 0         195  ...   both  Mid-range product  Regularly busy
# 1         195  ...   both  Mid-range product  Regularly busy
# 2         195  ...   both  Mid-range product  Regularly busy
# 3         195  ...   both  Mid-range product      Least busy
# 4         195  ...   both  Mid-range product      Least busy
#
#          busiest_days busiest_period_of_day max_order  loyalty_flag  \
# 0  Regularly busy day        Average orders        10  New customer
# 1     Least busy days        Average orders        10  New customer
# 2     Least busy days           Most orders        10  New customer
# 3     Least busy days        Average orders        10  New customer
# 4     Least busy days           Most orders        10  New customer
#
#   mean_price spender_flag  median_days
# 0   6.391379  Low Spender         20.0
# 1   6.391379  Low Spender         20.0
# 2   6.391379  Low Spender         20.0
# 3   6.391379  Low Spender         20.0
# 4   6.391379  Low Spender         20.0
#
# [5 rows x 24 columns]

# %%
# Create flags to assign "freqency" labels to user ID based on median days since prior order
ords_prods_merge.loc[ords_prods_merge['median_days'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days'] > 10) & (ords_prods_merge['median_days'] <= 20), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Check frequencies of spending flags for accuracy
ords_prods_merge['frequency_flag'].value_counts(dropna=False)
# Out:
# Frequent customer        21141387
# Regular customer          7057103
# Non-frequent customer     3562776
# NaN                            11
# Name: frequency_flag, dtype: int64

# %%
# Examining the null values
print(ords_prods_merge[ords_prods_merge.frequency_flag.isnull()])
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 363409      228286   163549             1                   5
# 3621357     228286   163549             1                   5
# 11394718    228286   163549             1                   5
# 13645692    895835   159838             1                   0
# 16410106    228286   163549             1                   5
# 17251990    895835   159838             1                   0
# 17622767    895835   159838             1                   0
# 23217772    824952   169017             1                   5
# 24138593    895835   159838             1                   0
# 24986390    228286   163549             1                   5
# 25880002    895835   159838             1                   0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 363409                   10                     NaN       13176
# 3621357                  10                     NaN       21137
# 11394718                 10                     NaN       26128
# 13645692                 17                     NaN       10749
# 16410106                 10                     NaN       20842
# 17251990                 17                     NaN       33401
# 17622767                 17                     NaN       23695
# 23217772                 13                     NaN       49621
# 24138593                 17                     NaN       21334
# 24986390                 10                     NaN       40969
# 25880002                 17                     NaN       22198
#
#           add_to_cart_order  reordered  Unnamed: 0  ...    price_range_loc  \
# 363409                    1          0       13176  ...  Mid-range product
# 3621357                   4          0       21138  ...  Mid-range product
# 11394718                  3          0       26129  ...  Mid-range product
# 13645692                  3          0       10749  ...  Mid-range product
# 16410106                  2          0       20843  ...  Mid-range product
# 17251990                  6          0       33403  ...  Mid-range product
# 17622767                  2          0       23696  ...  Low-range product
# 23217772                  1          0       49625  ...  Low-range product
# 24138593                  5          0       21335  ...  Mid-range product
# 24986390                  5          0       40973  ...  Low-range product
# 25880002                  1          0       22199  ...  Low-range product
#
#              busiest_day        busiest_days  busiest_period_of_day max_order  \
# 363409    Regularly busy  Regularly busy day            Most orders         1
# 3621357   Regularly busy  Regularly busy day            Most orders         1
# 11394718  Regularly busy  Regularly busy day            Most orders         1
# 13645692     Busiest day        Busiest days         Average orders         1
# 16410106  Regularly busy  Regularly busy day            Most orders         1
# 17251990     Busiest day        Busiest days         Average orders         1
# 17622767     Busiest day        Busiest days         Average orders         1
# 23217772  Regularly busy  Regularly busy day            Most orders         1
# 24138593     Busiest day        Busiest days         Average orders         1
# 24986390  Regularly busy  Regularly busy day            Most orders         1
# 25880002     Busiest day        Busiest days         Average orders         1
#
#           loyalty_flag mean_price spender_flag median_days  frequency_flag
# 363409    New customer       9.68  Low Spender         NaN             NaN
# 3621357   New customer       9.68  Low Spender         NaN             NaN
# 11394718  New customer       9.68  Low Spender         NaN             NaN
# 13645692  New customer       7.42  Low Spender         NaN             NaN
# 16410106  New customer       9.68  Low Spender         NaN             NaN
# 17251990  New customer       7.42  Low Spender         NaN             NaN
# 17622767  New customer       7.42  Low Spender         NaN             NaN
# 23217772  New customer       1.60  Low Spender         NaN             NaN
# 24138593  New customer       7.42  Low Spender         NaN             NaN
# 24986390  New customer       9.68  Low Spender         NaN             NaN
# 25880002  New customer       7.42  Low Spender         NaN             NaN
#
# [11 rows x 25 columns]

# %% [markdown]
# # The null values for 'frequency flag' and 'median days' for New Customers had only 1 order as days_since_prior_order is null, median cannot be calculated.

# %%
# Changing the null values in "frequency_flag" column to "Non-frequent customer"
ords_prods_merge['frequency_flag'].fillna("Non-frequent customer", inplace = True)

# %%
ords_prods_merge['frequency_flag'].value_counts(dropna=False)
# Out:
# Frequent customer        21141387
# Regular customer          7057103
# Non-frequent customer     3562787
# Name: frequency_flag, dtype: int64

# %%
# Finding Outliers
ords_prods_merge.loc[ords_prods_merge['prices'] > 100]
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order, product_id, add_to_cart_order, reordered, Unnamed: 0, product_name, aisle_id, department_id, prices, _merge, price_range_loc, busiest_day, busiest_days, busiest_period_of_day, max_order, loyalty_flag, mean_price, spender_flag, median_days, frequency_flag]
# Index: []
#
# [0 rows x 25 columns]

# %%
# Marking Outliers as missing to prevent skewing of data
ords_prods_merge.loc[ords_prods_merge['prices'] >100, 'prices'] = np.nan

# %%
ords_prods_merge['prices'].max()
# Out:
# 25.0

# %%
# Export data to pkl
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_aggregated.pkl'))
